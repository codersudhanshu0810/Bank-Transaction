# %% [markdown]
# # Importing Necessary Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime

# %% [markdown]
# # Loading Dataset

# %%
df = pd.read_csv('bank_transactions.csv')
df
# Out:
#          TransactionID  CustomerID CustomerDOB CustGender   CustLocation  \
# 0                    1     5841053  10-01-1994          F     JAMSHEDPUR
# 1                    2     2142763  04-04-1957          M        JHAJJAR
# 2                    3     4417068  26-11-1996          F         MUMBAI
# 3                    4     5342380  14-09-1973          F         MUMBAI
# 4                    5     9031234  24-03-1988          F    NAVI MUMBAI
# ...                ...         ...         ...        ...            ...
# 1041609        1048563     8020229  08-04-1990          M      NEW DELHI
# 1041610        1048564     6459278  20-02-1992          M         NASHIK
# 1041611        1048565     6412354  18-05-1989          M      HYDERABAD
# 1041612        1048566     6420483  30-08-1978          M  VISAKHAPATNAM
# 1041613        1048567     8337524  05-03-1984          M           PUNE
#
#          CustAccountBalance TransactionDate  TransactionAmount (INR)
# ...

# %% [markdown]
# # Handling Null Values or isnull()

# %%
df.isnull().sum()
# Out:
# TransactionID              0
# CustomerID                 0
# CustomerDOB                0
# CustGender                 0
# CustLocation               0
# CustAccountBalance         0
# TransactionDate            0
# TransactionAmount (INR)    0
# dtype: int64

# %%
df.to_csv('bank_transactions.csv', index=False)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1041614 entries, 0 to 1041613
# Data columns (total 8 columns):
#  #   Column                   Non-Null Count    Dtype
# ---  ------                   --------------    -----
#  0   TransactionID            1041614 non-null  int64
#  1   CustomerID               1041614 non-null  int64
#  2   CustomerDOB              1041614 non-null  object
#  3   CustGender               1041614 non-null  object
#  4   CustLocation             1041614 non-null  object
#  5   CustAccountBalance       1041614 non-null  float64
#  6   TransactionDate          1041614 non-null  object
#  7   TransactionAmount (INR)  1041614 non-null  int64
# dtypes: float64(1), int64(3), object(4)
# memory usage: 63.6+ MB

# %%
df['CustomerDOB'] = df['CustomerDOB'].str.replace('/', '-')
df
# Out:
#          TransactionID  CustomerID CustomerDOB CustGender   CustLocation  \
# 0                    1     5841053  10-01-1994          F     JAMSHEDPUR
# 1                    2     2142763  04-04-1957          M        JHAJJAR
# 2                    3     4417068  26-11-1996          F         MUMBAI
# 3                    4     5342380  14-09-1973          F         MUMBAI
# 4                    5     9031234  24-03-1988          F    NAVI MUMBAI
# ...                ...         ...         ...        ...            ...
# 1041609        1048563     8020229  08-04-1990          M      NEW DELHI
# 1041610        1048564     6459278  20-02-1992          M         NASHIK
# 1041611        1048565     6412354  18-05-1989          M      HYDERABAD
# 1041612        1048566     6420483  30-08-1978          M  VISAKHAPATNAM
# 1041613        1048567     8337524  05-03-1984          M           PUNE
#
#          CustAccountBalance TransactionDate  TransactionAmount (INR)
# ...

# %%
df['CustomerDOB'] = pd.to_datetime(df['CustomerDOB'], format='%d-%m-%Y')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1041614 entries, 0 to 1041613
# Data columns (total 8 columns):
#  #   Column                   Non-Null Count    Dtype
# ---  ------                   --------------    -----
#  0   TransactionID            1041614 non-null  int64
#  1   CustomerID               1041614 non-null  int64
#  2   CustomerDOB              1041614 non-null  datetime64[ns]
#  3   CustGender               1041614 non-null  object
#  4   CustLocation             1041614 non-null  object
#  5   CustAccountBalance       1041614 non-null  float64
#  6   TransactionDate          1041614 non-null  object
#  7   TransactionAmount (INR)  1041614 non-null  int64
# dtypes: datetime64[ns](1), float64(1), int64(3), object(3)
# memory usage: 63.6+ MB

# %%
df['TransactionDate'] = pd.to_datetime(df['TransactionDate'], format='%d-%m-%Y')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1041614 entries, 0 to 1041613
# Data columns (total 8 columns):
#  #   Column                   Non-Null Count    Dtype
# ---  ------                   --------------    -----
#  0   TransactionID            1041614 non-null  int64
#  1   CustomerID               1041614 non-null  int64
#  2   CustomerDOB              1041614 non-null  datetime64[ns]
#  3   CustGender               1041614 non-null  object
#  4   CustLocation             1041614 non-null  object
#  5   CustAccountBalance       1041614 non-null  float64
#  6   TransactionDate          1041614 non-null  datetime64[ns]
#  7   TransactionAmount (INR)  1041614 non-null  int64
# dtypes: datetime64[ns](2), float64(1), int64(3), object(2)
# memory usage: 63.6+ MB

# %% [markdown]
# # Value Counts

# %%
gdf = df['CustGender'].value_counts()
gdf = gdf.reset_index()
gdf
# Out:
#   CustGender   count
# 0          M  760978
# 1          F  280635
# 2          T       1

# %%
plt.figure(figsize=(15,5))
plt.plot(gdf['CustGender'], gdf['count'])
plt.xlabel('Customer Gender')
plt.ylabel('Count')
plt.title('Count according to Gender')
plt.show()

# %%
df
# Out:
#          TransactionID  CustomerID CustomerDOB CustGender   CustLocation  \
# 0                    1     5841053  1994-01-10          F     JAMSHEDPUR
# 1                    2     2142763  1957-04-04          M        JHAJJAR
# 2                    3     4417068  1996-11-26          F         MUMBAI
# 3                    4     5342380  1973-09-14          F         MUMBAI
# 4                    5     9031234  1988-03-24          F    NAVI MUMBAI
# ...                ...         ...         ...        ...            ...
# 1041609        1048563     8020229  1990-04-08          M      NEW DELHI
# 1041610        1048564     6459278  1992-02-20          M         NASHIK
# 1041611        1048565     6412354  1989-05-18          M      HYDERABAD
# 1041612        1048566     6420483  1978-08-30          M  VISAKHAPATNAM
# 1041613        1048567     8337524  1984-03-05          M           PUNE
#
#          CustAccountBalance TransactionDate  TransactionAmount (INR)
# ...

# %%
ldf = df['CustLocation'].value_counts().head(15)
ldf = ldf.reset_index()
ldf
# Out:
#    CustLocation   count
# 0        MUMBAI  101997
# 1     NEW DELHI   84143
# 2     BANGALORE   81330
# 3       GURGAON   73594
# 4         DELHI   70549
# 5         NOIDA   32656
# 6       CHENNAI   29840
# 7          PUNE   25690
# 8     HYDERABAD   22976
# 9         THANE   21397
# 10      KOLKATA   19851
# 11    GHAZIABAD   15722
# 12  NAVI MUMBAI   12916
# 13    AHMEDABAD   12145
# 14    FARIDABAD   11226

# %%
plt.figure(figsize=(20,5))
plt.bar(ldf['CustLocation'], ldf['count'])
plt.xlabel('Customer Location')
plt.ylabel('Count')
plt.title('Count according to Location')
plt.savefig('Bank_Transaction.png', format='png')

# %%
tdf = df.groupby('CustGender').agg(Transaction_Amount = ('TransactionAmount (INR)', 'sum'))
tdf = tdf.reset_index().sort_values(by='Transaction_Amount', ascending=False)
tdf
# Out:
#   CustGender  Transaction_Amount
# 1          M          1169837434
# 0          F           461334316
# 2          T               32500

# %%
plt.figure(figsize=(10,5))
plt.bar(tdf['CustGender'], tdf['Transaction_Amount'])
plt.xlabel('Customer Gender')
plt.ylabel('Transaction Amount')
plt.title('Transaction according to the Gender')
plt.savefig('Transaction according to Gender.png', format='png')

# %%
ydf = df.groupby('CustLocation').agg(Transact_Amount = ('TransactionAmount (INR)', 'sum'))
ydf = ydf.reset_index().sort_values(by='Transact_Amount', ascending=False).head(10)
ydf
# Out:
#      CustLocation  Transact_Amount
# 5219       MUMBAI        174726745
# 5738    NEW DELHI        158468204
# 770     BANGALORE        117480614
# 3058      GURGAON        111444495
# 2055        DELHI        105157761
# 4231      KOLKATA         60316784
# 1591      CHENNAI         44268924
# 5833        NOIDA         44245182
# 6656         PUNE         39063800
# 3367    HYDERABAD         35971837

# %%
plt.figure(figsize=(15,5))
plt.bar(ydf['CustLocation'], ydf['Transact_Amount'])
plt.xlabel('Customer Location')
plt.ylabel('Transaction Amount')
plt.title('Transaction according to the Location')
plt.savefig('Transaction according to Location.png', format='png')
